# %%
import pandas as pd
import npstat

# %%
df = pd.read_csv('Data/Educational Intervention on Menstrual health .csv')
df = df.dropna()

# %%
df.columns
# Out:
# Index(['Internet Access ', '1. Age',
#        'If you have periods twice in 21 days do you think that is normal',
#        'Education Level ', 'Area ',
#        'What kind of medication you should take during periods',
#        'After how long should you change your sanitary napkin.',
#        'Should you be expecting big quarter size clots in your periods blood ?',
#        'Blood loss of how many mls during periods is considered normal',
#        'Do women have periods during pregnancy or when they're lactating',
#        'How many phases are there in menstrual cycle',
#        ' In what phase the chances to conceive are maximum',
#        'What is the average menstrual cycle duration?',
#        'Should you bath regularly during menstruation?',
#        'If you have periods twice in 21 days do you think that is normal.1',
#        'What kind of medication you should take during periods.1',
#        'After how long should you change your sanitary napkin..1',
# ...

# %%
cls = ['Internet Access ', '1. Age',
       'Education Level ', 'Area ']
test = ['If you have periods twice in 21 days do you think that is normal',
        'What kind of medication you should take during periods',
       'After how long should you change your sanitary napkin.',
       'Should you be expecting big quarter size clots in your periods blood ?',
       'Blood loss of how many mls during periods is considered normal',
       "Do women have periods during pregnancy or when they're lactating",
       'How many phases are there in menstrual cycle',
       ' In what phase the chances to conceive are maximum',
       'What is the average menstrual cycle duration?',
       'Should you bath regularly during menstruation?',
       'If you have periods twice in 21 days do you think that is normal.1',
       'What kind of medication you should take during periods.1',
       'After how long should you change your sanitary napkin..1',
       'Should you be expecting big quarter size clots in your periods blood ?.1',
       'Blood loss of how many mls during periods is considered normal.1',
       "Do women have periods during pregnancy or when they're lactating.1",
       'How many phases are there in menstrual cycle.1',
       ' In what phase the chances to conceive are maximum.1',
       'What is the average menstrual cycle duration?.1',
       'Should you bath regularly during menstruation?.1']

# %%
results = npstat.chi_square(df, cls, test)

# %%
results
# Out:
# <style type="text/css">
# #T_167d5_row4_col2, #T_167d5_row29_col2, #T_167d5_row44_col2, #T_167d5_row53_col2, #T_167d5_row56_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_167d5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_167d5_level0_col0" class="col_heading level0 col0" >Degree of Freedom</th>
#       <th id="T_167d5_level0_col1" class="col_heading level0 col1" >chi square</th>
#       <th id="T_167d5_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_167d5_level0_row0" class="row_heading level0 row0" rowspan="4">If you have periods twice in 21 days do you think that is normal</th>
#       <th id="T_167d5_level1_row0" class="row_heading level1 row0" >Internet Access </th>
#       <td id="T_167d5_row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
results.to_excel('Data/sami_fyp.xlsx')
